# %% [markdown]
# ###**Name: Nilesh Sharad Mahajan**
# ###**Task 1: Prediction using Supervised ML**
# **Internship at The Sparks Foundation**
#
# **Q: Predict the percentage of an student based on the no. of study hours. What will be predicted score if a student studies for 9.25 hrs/day?**

# %%
#importing all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading data from dataset
student_data=pd.read_csv("/content/student_scores - student_scores.csv")

# %%
student_data.head(5)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
student_data.shape
# Out:
# (25, 2)

# %%
student_data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#plotting the dataset
student_data.plot(x='Hours',y='Scores',style='o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours studied')
plt.ylabel('Percentage score')
plt.show()

# %% [markdown]
# **Preparing the Data**

# %%
x=student_data.drop('Scores',axis=1)
y=student_data['Scores']

# %%
#spliting the data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.20)

# %% [markdown]
# **Training the Model**

# %%
#building linear regression model
sklearn.linear_model import LinearRegression
lin_model=LinearRegression()
lin_model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#plotting the regression line
a=lin_model.coef_*x+lin_model.intercept_
#plotting for test data
plt.scatter(x,y,color='red')
plt.plot(x,a)
plt.show()

# %% [markdown]
# **Model Prediction**

# %%
y_pred=lin_model.predict(x_test)
print(y_pred)
# Out:
# [84.27660883 79.32128059 62.47316457 56.52677068 36.70545772]

# %%
#comparing the results
result=pd.DataFrame()
result['Actual']=y_test
result['Predicted']=y_pred
result
# Out:
#     Actual  Predicted
# 5       20  16.884145
# 2       27  33.732261
# 19      69  75.357018
# 16      30  26.794801
# 11      62  60.491033

# %%
# checking with sample values
hours=[[9.25]]
pred=lin_model.predict(hours)
print("Predicted Score=",pred)
# Out:
# Predicted Score= [93.69173249]

# %% [markdown]
# **Model Evaluation**

# %%
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error:",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982

# %%
from sklearn.metrics import mean_squared_error
import math
print("Mean Squared Error:",(math.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# Mean Squared Error: 4.647447612100373
